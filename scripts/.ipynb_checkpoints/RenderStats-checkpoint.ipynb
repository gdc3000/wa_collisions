# %% [markdown]
# This module will perform

# %%
import pandas as pd
from neighborhood_reader import get_neighborhood, assign_neighborhood
from causalimpact import CausalImpact
import geopandas as gpd

# %% [markdown]
# ## Step 1: Import data

# %%
df = pd.read_csv("../wa_collisions/data/Collisions_With_Neighborhoods.csv")

# %%
df.head(1).T
# Out:
#                                                                  0
# Unnamed: 0                                                       0
# X                                                         -122.342
# Y                                                          47.6276
# objectid                                                 162244138
# inckey                                                      233006
# coldetkey                                                   233406
# addrtype                                                     Block
# collisiontype                                              Head On
# exceptrsncode
# exceptrsndesc                                                  NaN
# fatalities                                                       0
# inattentionind                                                 NaN
# incdate                                   2016-11-04T00:00:00.000Z
# incdttm                                       11/4/2016 9:55:00 AM
# injuries                                                         0
# intkey                                                         NaN
# junctiontype               Mid-Block (not related to intersection)
# lightcond                                                 Daylight
# location                 DEXTER AVE N BETWEEN ALOHA ST AND WARD ST
# pedcount                                                         0
# pedcylcount                                                      0
# pedrownotgrnt                                                  NaN
# personcount                                                      2
# reportno                                                   E605707
# roadcond                                                       Dry
# sdot_colcode                                                    11
# sdot_coldesc     MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...
# sdotcolnum                                                     NaN
# seriousinjuries                                                  0
# severitycode                                                     1
# severitydesc                        Property Damage Only Collision
# speeding                                                       NaN
# st_colcode                                                      30
# st_coldesc                    From Opposite Direction - All Others
# status                                                     Matched
# underinfl                                                        N
# vehcount                                                         2
# weather                                     Clear or Partly Cloudy
# seglanekey                                                       0
# crosswalkkey                                                     0
# hitparkedcar                                                     N
# object_id                                                       47

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'X', 'Y', 'objectid', 'inckey', 'coldetkey', 'addrtype',
#        'collisiontype', 'exceptrsncode', 'exceptrsndesc', 'fatalities',
#        'inattentionind', 'incdate', 'incdttm', 'injuries', 'intkey',
#        'junctiontype', 'lightcond', 'location', 'pedcount', 'pedcylcount',
#        'pedrownotgrnt', 'personcount', 'reportno', 'roadcond', 'sdot_colcode',
#        'sdot_coldesc', 'sdotcolnum', 'seriousinjuries', 'severitycode',
#        'severitydesc', 'speeding', 'st_colcode', 'st_coldesc', 'status',
#        'underinfl', 'vehcount', 'weather', 'seglanekey', 'crosswalkkey',
#        'hitparkedcar', 'object_id'],
#       dtype='object')

# %%
NEIGHBORHOODS = gpd.read_file('../wa_collisions/data/Neighborhoods/Neighborhoods.json')
NEIGHBORHOODS_COUNT = len(NEIGHBORHOODS)

# %% [markdown]
# ## Step 2: Data clean-up

# %% [markdown]
# ### Identify neighborhoods where speed limits changed

# %% [markdown]
# Identify neighborhoods where speed limit changed and those where it didn't

# %%
speed_limit_nbrhood = ['Atlantic','Pike-Market', 'Belltown', 'International District',
       'Central Business District', 'First Hill', 'Yesler Terrace',
       'Pioneer Square', 'Interbay','Mann','Minor']
no_speed_limit_nbrhood = list(set(NEIGHBORHOODS['S_HOOD'].unique()) - set(speed_limit_nbrhood))

# %% [markdown]
# Convert names to object ids

# %%
speed_limit_nbrhood_id = []
for i in range(0,len(speed_limit_nbrhood)):
    speed_limit_nbrhood_id = speed_limit_nbrhood_id + [int(NEIGHBORHOODS[NEIGHBORHOODS['S_HOOD'] == speed_limit_nbrhood[i]]['OBJECTID'])]
no_speed_limit_nbrhood = list(set(NEIGHBORHOODS['OBJECTID'].unique()) - set(speed_limit_nbrhood_id))

# %% [markdown]
# ### Add speed limit flag to dataframe and group collisions data by date

# %%
df['speedlimit_change_flag'] =  df['object_id'].isin(speed_limit_nbrhood_id)

# %%
df.head(1).T
# Out:
#                                                                         0
# Unnamed: 0                                                              0
# X                                                                -122.342
# Y                                                                 47.6276
# objectid                                                        162244138
# inckey                                                             233006
# coldetkey                                                          233406
# addrtype                                                            Block
# collisiontype                                                     Head On
# exceptrsncode
# exceptrsndesc                                                         NaN
# fatalities                                                              0
# inattentionind                                                        NaN
# incdate                                          2016-11-04T00:00:00.000Z
# incdttm                                              11/4/2016 9:55:00 AM
# injuries                                                                0
# intkey                                                                NaN
# junctiontype                      Mid-Block (not related to intersection)
# lightcond                                                        Daylight
# location                        DEXTER AVE N BETWEEN ALOHA ST AND WARD ST
# pedcount                                                                0
# pedcylcount                                                             0
# pedrownotgrnt                                                         NaN
# personcount                                                             2
# reportno                                                          E605707
# roadcond                                                              Dry
# sdot_colcode                                                           11
# sdot_coldesc            MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...
# sdotcolnum                                                            NaN
# seriousinjuries                                                         0
# severitycode                                                            1
# severitydesc                               Property Damage Only Collision
# speeding                                                              NaN
# st_colcode                                                             30
# st_coldesc                           From Opposite Direction - All Others
# status                                                            Matched
# underinfl                                                               N
# vehcount                                                                2
# weather                                            Clear or Partly Cloudy
# seglanekey                                                              0
# crosswalkkey                                                            0
# hitparkedcar                                                            N
# object_id                                                              47
# speedlimit_change_flag                                              False

# %%
print('min date:',df['incdate'].min())
print('max date:',df['incdate'].max())
# Out:
# min date: 2003-10-06 00:00:00
# max date: 2018-03-29 00:00:00

# %% [markdown]
# ### Define periods before and after speed limit change

# %%
pre_period  = [pd.to_datetime(date) for date in ["2013-10-06", "2016-09-30"]]
post_period = [pd.to_datetime(date) for date in ["2016-10-01", "2018-03-29"]]

# %%
df['incdate'] = pd.to_datetime(df['incdate'])

# %% [markdown]
# ### Create dataframe for input to causal impact

# %%
#def create_causal_impact_frame(input_frame,)
data_all = df.groupby(['incdate','speedlimit_change_flag']).size()
data_all = data_all.unstack()
data_all = data_all.fillna(0)
data_all = data_all.rename(columns={True: "SpeedLimitChange", False: "SpeedLimitSame"})
data_all = data_all[['SpeedLimitChange','SpeedLimitSame']]

# %%
data_all.head(1)
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# incdate
# 2003-10-06                           1.0             0.0

# %%
data_all.corr()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# speedlimit_change_flag
# SpeedLimitChange                 1.00000         0.38939
# SpeedLimitSame                   0.38939         1.00000

# %% [markdown]
# ### Run causal impact by day

# %%
impact = CausalImpact(data_all, pre_period, post_period)
impact.run()

# %%
impact.summary()
# Out:
#                          Average       Cumulative
# Actual                         6             3793
# Predicted                      6             3707
# 95% CI                   [0, 13]      [266, 7148]
#
# Absolute Effect                0               85
# 95% CI                   [6, -6]    [3526, -3355]
#
# Relative Effect             2.3%             2.3%
# 95% CI           [95.1%, -90.5%]  [95.1%, -90.5%]

# %%
impact.plot()

# %% [markdown]
# ### Group data by week and month

# %%
data_week = data_all.resample('W', how='sum')
data_month = data_all.resample('M', how='sum')
# Out:
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   """Entry point for launching an IPython kernel.
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()

# %%
##Find the end of the pre_period in terms of weeks, months

# %%
pre_period_wk  = [pd.to_datetime(date) for date in ["2003-10-12", "2016-10-02"]]
post_period_wk = [pd.to_datetime(date) for date in ["2016-10-09", "2018-04-01"]]

pre_period_month  = [pd.to_datetime(date) for date in ["2003-10-31", "2016-09-30"]]
post_period_month = [pd.to_datetime(date) for date in ["2016-10-31", "2018-03-31"]]

# %%
data_week.head()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# incdate
# 2003-10-12                           1.0             0.0
# 2003-10-19                           0.0             0.0
# 2003-10-26                           0.0             0.0
# 2003-11-02                           0.0             0.0
# 2003-11-09                           0.0             0.0

# %% [markdown]
# ### Re-analyze by week

# %%
impact_wk = CausalImpact(data_week, pre_period_wk, post_period_wk)
impact_wk.run()

# %%
impact_wk.summary()
# Out:
#                          Average       Cumulative
# Actual                        48             3781
# Predicted                     46             3599
# 95% CI                  [28, 63]     [2210, 4987]
#
# Absolute Effect                2              181
# 95% CI                 [20, -15]    [1570, -1206]
#
# Relative Effect             5.0%             5.0%
# 95% CI           [43.6%, -33.5%]  [43.6%, -33.5%]

# %%
impact_wk.plot()

# %%
impact_mth = CausalImpact(data_month, pre_period_month, post_period_month)
impact_mth.run()

# %%
impact_mth.summary()
# Out:
#                          Average       Cumulative
# Actual                       210             3793
# Predicted                    209             3768
# 95% CI                [169, 248]     [3055, 4480]
#
# Absolute Effect                1               24
# 95% CI                 [40, -38]      [737, -687]
#
# Relative Effect             0.7%             0.7%
# 95% CI           [19.6%, -18.2%]  [19.6%, -18.2%]

# %%
impact_mth.plot()

# %% [markdown]
# ### What happens when we look at speeding by month?

# %%
df.groupby('injuries').size()
# Out:
# injuries
# 0     141755
# 1      41325
# 2       9431
# 3       2454
# 4        738
# 5        247
# 6         91
# 7         37
# 8         12
# 9         10
# 10         6
# 11         5
# 12         1
# 13         2
# 15         1
# 78         1
# dtype: int64

# %%
df.size
# Out:
# 8432988

# %%
df_in = df[df['speeding']=='Y']
data_all = df_in.groupby(['incdate','speedlimit_change_flag']).size()
data_all = data_all.unstack()
data_all = data_all.fillna(0)
data_all = data_all.rename(columns={True: "SpeedLimitChange", False: "SpeedLimitSame"})
data_all = data_all[['SpeedLimitChange','SpeedLimitSame']]

# %%
data_month = data_all.resample('M', how='sum')
# Out:
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   """Entry point for launching an IPython kernel.

# %%
data_month.tail()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# incdate
# 2017-09-30                           0.0             0.0
# 2017-10-31                           3.0            21.0
# 2017-11-30                          11.0            50.0
# 2017-12-31                           6.0            49.0
# 2018-01-31                           6.0            42.0

# %%
pre_period_month  = [pd.to_datetime(date) for date in ["2004-01-31", "2016-09-30"]]
post_period_month = [pd.to_datetime(date) for date in ["2016-10-31", "2018-01-31"]]

# %%
impact_mth = CausalImpact(data_month, pre_period_month, post_period_month)
impact_mth.run()

# %%
impact_mth.summary()
# Out:
#                           Average        Cumulative
# Actual                          5                82
# Predicted                       6                97
# 95% CI                    [0, 12]        [-11, 206]
#
# Absolute Effect                 0               -15
# 95% CI                    [5, -7]        [93, -124]
#
# Relative Effect            -15.8%            -15.8%
# 95% CI           [95.6%, -127.3%]  [95.6%, -127.3%]

# %%
impact_mth.plot()

# %% [markdown]
# ### What happens when we look at accidents with injuries per month?

# %%
df_in = df[df['injuries']>0]
data_all = df_in.groupby(['incdate','speedlimit_change_flag']).size()
data_all = data_all.unstack()
data_all = data_all.fillna(0)
data_all = data_all.rename(columns={True: "SpeedLimitChange", False: "SpeedLimitSame"})
data_all = data_all[['SpeedLimitChange','SpeedLimitSame']]

# %%
data_month = data_all.resample('M', how='sum')
# Out:
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   """Entry point for launching an IPython kernel.

# %%
data_month.tail()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# incdate
# 2017-11-30                          79.0           241.0
# 2017-12-31                          63.0           242.0
# 2018-01-31                          56.0           246.0
# 2018-02-28                          26.0           138.0
# 2018-03-31                          12.0            61.0

# %%
data_month.plot()

# %%
data_month.corr()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# speedlimit_change_flag
# SpeedLimitChange                1.000000        0.699349
# SpeedLimitSame                  0.699349        1.000000

# %%
pre_period_month  = [pd.to_datetime(date) for date in ["2004-01-31", "2016-09-30"]]
post_period_month = [pd.to_datetime(date) for date in ["2016-10-31", "2018-01-31"]]

# %%
impact_mth = CausalImpact(data_month, pre_period_month, post_period_month,model_args={"nseasons":12})
impact_mth.run()

# %%
impact_mth.summary()
# Out:
#                          Average       Cumulative
# Actual                        58              930
# Predicted                     63             1022
# 95% CI                  [46, 81]      [743, 1301]
#
# Absolute Effect               -5              -92
# 95% CI                 [11, -23]      [186, -371]
#
# Relative Effect            -9.1%            -9.1%
# 95% CI           [18.2%, -36.3%]  [18.2%, -36.3%]

# %%
impact_mth.plot(["original","cumulative", "pointwise"])

# %% [markdown]
# ### What happens when we look at number of injuries?

# %%
df_in = df[df['injuries']>0]
data_all = df_in.groupby(['incdate','speedlimit_change_flag'])['injuries'].sum()
data_all = data_all.unstack()
data_all = data_all.fillna(0)
data_all = data_all.rename(columns={True: "SpeedLimitChange", False: "SpeedLimitSame"})
data_all = data_all[['SpeedLimitChange','SpeedLimitSame']]

# %%
data_month = data_all.resample('M', how='sum')
# Out:
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   """Entry point for launching an IPython kernel.

# %%
data_month.corr()
# Out:
# speedlimit_change_flag  SpeedLimitChange  SpeedLimitSame
# speedlimit_change_flag
# SpeedLimitChange                1.000000        0.681083
# SpeedLimitSame                  0.681083        1.000000

# %%
impact_mth = CausalImpact(data_month, pre_period_month, post_period_month,model_args={"nseasons":12})
impact_mth.run()

# %%
impact_mth.summary()
# Out:
#                          Average       Cumulative
# Actual                        75             1205
# Predicted                     80             1288
# 95% CI                 [54, 106]      [872, 1704]
#
# Absolute Effect               -5              -83
# 95% CI                 [20, -31]      [332, -499]
#
# Relative Effect            -6.5%            -6.5%
# 95% CI           [25.8%, -38.8%]  [25.8%, -38.8%]

# %%
impact_mth.plot(["original","cumulative", "pointwise"])

# %%
summary(impact_mth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-301-171acf9f200b> in <module>()
# ----> 1 summary(impact_mth)
#
# NameError: name 'summary' is not defined
